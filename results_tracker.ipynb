# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("All Predictions.csv")
df.head()
# Out:
#    Unnamed: 0   PCON24CD              constituency      LAT     LONG region  \
# 0           0  E14001063                 Aldershot  51.2903 -0.78648     SE
# 1           1  E14001064       Aldridge-Brownhills  52.6071 -1.93173     WM
# 2           2  E14001065  Altrincham and Sale West  53.3977 -2.39049     NW
# 3           3  E14001066              Amber Valley  53.0428 -1.39771     EM
# 4           4  E14001067   Arundel and South Downs  50.9580 -0.61585     SE
#
#    country 2019_winner 2019_majority  turnout  ...  mean_diff   mean_Con  \
# 0  England         con         17985     67.5  ...  11.392000  31.066667
# 1  England         con         22758     64.7  ...  18.409333  36.586667
# 2  England         con          6139     74.1  ...  18.762667  27.026667
# 3  England         con         16891     64.6  ...  17.256000  29.420000
# 4  England         con         24105     75.5  ...  20.744000  32.533333
#
# ...

# %%
res = pd.read_csv("Results.csv")
res = res[["constituency", "2024_winner"]]
res = pd.merge(res, df)

# %%
len(res[res["mean_Winner"] == res["2024_winner"]]) / 632
# Out:
# 0.8876582278481012

# %%
for model in ['BP', 'EM', 'E', 'Y', 'S', 'MC']:
    print(f'{model}:\t{len(res[res[f"{model}_Winner"] == res["2024_winner"]]) / 632}')
# Out:
# BP:	0.8639240506329114
# EM:	0.8892405063291139
# E:	0.8639240506329114
# Y:	0.8908227848101266
# S:	0.8259493670886076
# MC:	0.8670886075949367
